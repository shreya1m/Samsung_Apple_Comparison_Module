# %% [markdown]
# # **Project Title:** : **Comparison Module: Analyzing Samsung and Apple in the Electronics Industry**

# %% [markdown]
# Project Type : Comparasion Module
#
# Contribution : Individual (Name-Shreya Kumari,shreyanarayan062@gmail.com)

# %% [markdown]
# # **Github Link :**

# %% [markdown]
# **Link :**  https://github.com/shreya1m/Samsung_Apple_Comparison_Module

# %% [markdown]
# # **Brief Overview of the Project:**

# %% [markdown]
# This project aims to conduct a comprehensive strategic analysis and comparative study of two leading companies in the technology industry: Samsung and Apple. Through detailed examination of their respective missions, visions, values, financial performance, market share, product offerings, and strategic initiatives, the project seeks to provide insights into their competitive positions, strengths, weaknesses, opportunities, and threats. By leveraging various analytical frameworks and tools, including Porter's Five Forces, SWOT analysis, financial analysis, and market share evaluation, the project aims to offer valuable insights for stakeholders, investors, industry analysts, and enthusiasts interested in understanding the dynamics of the technology industry and the competitive strategies employed by Samsung and Apple.

# %% [markdown]
# # **APPLE**

# %% [markdown]
# * **Apple is a globally renowned brand**, credited with revolutionizing the smartphone industry with the iPhone and boasting a staggering valuation of over **$2 trillion in 2021**.
#
# * Initially recognized for its desktop computers, Apple embraced the graphical user interface (GUI) early on, achieving success with the introduction of the Macintosh.
#
# * **Founder and CEO Steve Jobs**, a pioneer in the tech industry, played a pivotal role in reshaping Apple's image and perception, elevating hardware beyond mere functionality to a status symbol.
#
# * Following Jobs' departure in 1985, Apple encountered a period of decline, struggling to compete with Microsoft in software and Windows-based manufacturers in hardware sales.
#
# * In a strategic move to revitalize the company, Apple acquired NeXT, a company founded by Jobs, and reinstated him as CEO. Jobs spearheaded the successful launch of iTunes and iPod in 2001.
#
# * **The iPhone's introduction propelled Apple to unprecedented heights, with revenue skyrocketing from 37.4 billion dollar in 2008 to 65 billion dollar in 2010.**
#
# * Leveraging the iPhone's success, Apple diversified its product portfolio by introducing innovative devices like the iPad, positioned as a hybrid between a smartphone and laptop.
#
# * With iPhone sales plateauing, Apple expanded its revenue streams by introducing complementary products like the Apple Watch and AirPods, pioneering wireless headphone technology.
#
# * Apple augmented its offerings with subscription-based services encompassing music and video streaming, gaming, fitness, and cloud storage, generating substantial revenue, notably $53 billion in 2020.
#
# * **Anticipation surrounds Apple's future product releases, including a potential virtual reality headset and self-driving car, following recent launches like the HomePod and AirPods.**

# %% [markdown]
# **Apple Overview**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Apple Key Statistics**
#
# * **Apple generated $383.2 billion revenue in 2023** , **52% came from iPhone sales**
#
# * Apple Services is the second largest division, **responsible for 22% of revenue in 2023**
# 232 million iPhones, 61 million iPads and 26 million Mac and MacBook units were sold in 2022
# * Apple’s home and wearables division declined by 3.6% in 2023
# * It sold 82 million AirPods and 53 million Apple Watches in 2022
# * Apple Music has 88 million subscribers, Apple TV+ has over 75 million
# * Apple has always been most successful in the United States, its home country. Americas is responsible for 42% of all revenue generation and approximately 35% of that is from the US alone.

# %% [markdown]
# ## Apple Market Capital Over Years

# %%
# Market Capital data

data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
    'Market Cap (in Billion $)': [174.03, 75.99, 190.98, 297.09, 377.51, 499.69, 500.74, 643.12, 583.61, 608.96, 860.88, 746.07, 1287, 2255, 2901, 2066, 2994, 2665]
}

# Create DataFrame
cap_AAPL_df = pd.DataFrame(data)

# Convert 'Year' to categorical variable
cap_AAPL_df['Year'] = cap_AAPL_df['Year'].astype(str)

# Display DataFrame
cap_AAPL_df
# Out:
#     Year  Market Cap (in Billion $)
# 0   2007                     174.03
# 1   2008                      75.99
# 2   2009                     190.98
# 3   2010                     297.09
# 4   2011                     377.51
# 5   2012                     499.69
# 6   2013                     500.74
# 7   2014                     643.12
# 8   2015                     583.61
# 9   2016                     608.96
# 10  2017                     860.88
# 11  2018                     746.07
# 12  2019                    1287.00
# 13  2020                    2255.00
# 14  2021                    2901.00
# 15  2022                    2066.00
# 16  2023                    2994.00
# 17  2024                    2665.00

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(cap_AAPL_df['Year'], cap_AAPL_df['Market Cap (in Billion $)'], marker='o', color='blue')
plt.title('Apple Market Capitalization Over Time')
plt.xlabel('Year')
plt.ylabel('Market Cap (in Billion $)')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Apple Annual Revenue Over Years

# %%
import pandas as pd

# data
data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Revenue': [24.4, 37.4, 42.7, 65, 108, 156.3, 170.8, 182.6, 233.6, 215.4, 229.2, 265.5, 260.1, 274.5, 365.8, 394.1, 383.2]
}

# Create DataFrame
revenue_AAPL_df = pd.DataFrame(data)

# Convert 'Year' to categorical variable
revenue_AAPL_df['Year'] = revenue_AAPL_df['Year'].astype(str)

# Display DataFrame
revenue_AAPL_df
# Out:
#     Year  Revenue
# 0   2007     24.4
# 1   2008     37.4
# 2   2009     42.7
# 3   2010     65.0
# 4   2011    108.0
# 5   2012    156.3
# 6   2013    170.8
# 7   2014    182.6
# 8   2015    233.6
# 9   2016    215.4
# 10  2017    229.2
# 11  2018    265.5
# 12  2019    260.1
# 13  2020    274.5
# 14  2021    365.8
# 15  2022    394.1
# 16  2023    383.2

# %%
# Plot
plt.figure(figsize=(10, 6))
plt.bar(revenue_AAPL_df['Year'], revenue_AAPL_df['Revenue'], color='skyblue')
plt.title('Apple Revenue Over the Years')
plt.xlabel('Year')
plt.ylabel('Revenue ($bn)')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Apple Net Income Over Years

# %%
import matplotlib.pyplot as plt

# Data
data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Net Income ($US Billion)': [3.5, 6.12, 8.24, 14.01, 25.92, 41.73, 37.04, 39.51, 53.39, 45.69, 48.35, 59.53, 53.26, 57.41, 94.68, 99.8, 96.99]
}

# Create DataFrame
net_income_AAPL_df = pd.DataFrame(data)

# Convert 'Year' to categorical variable
net_income_AAPL_df['Year'] = net_income_AAPL_df['Year'].astype(str)

# Display dataframe
net_income_AAPL_df
# Out:
#     Year  Net Income ($US Billion)
# 0   2007                      3.50
# 1   2008                      6.12
# 2   2009                      8.24
# 3   2010                     14.01
# 4   2011                     25.92
# 5   2012                     41.73
# 6   2013                     37.04
# 7   2014                     39.51
# 8   2015                     53.39
# 9   2016                     45.69
# 10  2017                     48.35
# 11  2018                     59.53
# 12  2019                     53.26
# 13  2020                     57.41
# 14  2021                     94.68
# 15  2022                     99.80
# 16  2023                     96.99

# %%
# Plot
plt.figure(figsize=(10, 6))
plt.bar(net_income_AAPL_df['Year'], net_income_AAPL_df['Net Income ($US Billion)'], color='skyblue')
plt.title('Apple Net Income Over Years')
plt.xlabel('Year')
plt.ylabel('Net Income ($US Billion)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Apple Stock Prices Over Years

# %%
import yfinance as yf

# Ticker symbol
ticker_symbol = 'AAPL'

# Fetch stock prices
stock_prices_AAPL = yf.download(ticker_symbol, start='2005-01-01', end='2024-03-16')

stock_prices_AAPL.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2005-01-03  1.156786  1.162679  1.117857  1.130179   0.956809   691992000
# 2005-01-04  1.139107  1.169107  1.124464  1.141786   0.966635  1096810400
# 2005-01-05  1.151071  1.165179  1.143750  1.151786   0.975102   680433600
# 2005-01-06  1.154821  1.159107  1.130893  1.152679   0.975857   705555200
# 2005-01-07  1.160714  1.243393  1.156250  1.236607   1.046910  2227450400

# %%
# Plot
plt.figure(figsize=(12, 6))
plt.plot(stock_prices_AAPL.index, stock_prices_AAPL['Close'], color='blue')
plt.title('Stock Prices of Apple Over Years')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **SAMSUNG**

# %% [markdown]
# * Samsung Electronics (005930) ranks as the **world's 24th most valuable company by market capitalization**, with a value of **$325.10 billion** as of May 28, 2023.
#
# * In 2022, Samsung's revenue reached ₩302.2 trillion (245.7 billion dollar), marking a substantial increase from $227.4 billion in 2021, solidifying its position as the **largest South Korean company by revenue**.
#
# * Despite facing challenges in the semiconductor industry, including falling prices and weak demand for memory chips, Samsung remains committed to investing ₩240 trillion over several years to expand its presence in biopharmaceuticals, artificial intelligence, semiconductors, display technologies, and robotics.
#
# * In Q3 2022, Samsung's revenue reached approximately $58 billion, demonstrating its continued strength in the market.
#
# * The company's investment of $22 billion in research and development underscores its commitment to maintaining leadership in the smartphone market.
#
# * Despite challenges in 2020 due to the pandemic, Samsung's revenue still amounted to a staggering $197.96 billion.
#
# * Samsung's semiconductor division saw significant growth in Q1 2023, with sales increasing by 23% year-over-year to ₩23.2 trillion.
#
# * The Samsung Galaxy Note series and Galaxy A series remain popular choices among consumers, contributing to Samsung's market dominance.
#
# * Samsung's brand value increased by 17% in 2022, reaching $87.7 billion, reflecting its strong brand recognition and customer loyalty.
#
# * Samsung aims to strengthen its leadership in technology globally through mergers, acquisitions, and strategic investments, with a focus on new spheres of robotics and next-generation 5G telecommunications.
#
# * The company's first-quarter operating profit in 2023 declined significantly to ₩640 billion or $478.55 million, the lowest since early 2009, primarily due to falling prices and weak demand for memory chips.
#
# * Despite the setback, Samsung anticipates a recovery in the second half of the year, driven by an increase in demand for consumer devices and a rebound in the semiconductor industry.
#
# * **With a market share of 27.14% at the beginning of 2023, Samsung continues to be a key player in the smartphone industry, closely trailing behind Apple**.

# %% [markdown]
# **Samsung** **Overview**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Samsung Market Capital Over Years

# %%
# Market Capital data

data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024],
    'Market Cap (in Billion $)': [78.61, 46.12, 90.12, 109.32, 130.66, 208.13, 189.44, 176.45, 153.77, 203.99, 319.26, 230.36, 319.73, 500.83, 442.07, 293.00, 401.54, 365.53]
}

# Create DataFrame
cap_SAM_df = pd.DataFrame(data)

# Convert 'Year' to categorical variable
cap_SAM_df['Year'] = cap_SAM_df['Year'].astype(str)

# Display DataFrame
cap_SAM_df
# Out:
#     Year  Market Cap (in Billion $)
# 0   2007                      78.61
# 1   2008                      46.12
# 2   2009                      90.12
# 3   2010                     109.32
# 4   2011                     130.66
# 5   2012                     208.13
# 6   2013                     189.44
# 7   2014                     176.45
# 8   2015                     153.77
# 9   2016                     203.99
# 10  2017                     319.26
# 11  2018                     230.36
# 12  2019                     319.73
# 13  2020                     500.83
# 14  2021                     442.07
# 15  2022                     293.00
# 16  2023                     401.54
# 17  2024                     365.53

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(cap_SAM_df['Year'], cap_SAM_df['Market Cap (in Billion $)'], marker='o', color='blue')
plt.title('Samsung Market Capitalization Over Time')
plt.xlabel('Year')
plt.ylabel('Market Cap (in Billion $)')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Samsung Annual Revenue Over year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data
data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Revenue': [106.73, 104.33, 113.64, 133.94, 146.43, 184.22, 210.86, 195.22, 174.66, 175.51, 214.57, 221.67, 198.03, 203.43, 240.71, 233.13, 196.77]
}

# Create DataFrame
revenue_SAM_df = pd.DataFrame(data)

# Convert 'Year' to categorical variable
revenue_SAM_df['Year'] = revenue_SAM_df['Year'].astype(str)

revenue_SAM_df
# Out:
#     Year  Revenue
# 0   2007   106.73
# 1   2008   104.33
# 2   2009   113.64
# 3   2010   133.94
# 4   2011   146.43
# 5   2012   184.22
# 6   2013   210.86
# 7   2014   195.22
# 8   2015   174.66
# 9   2016   175.51
# 10  2017   214.57
# 11  2018   221.67
# 12  2019   198.03
# 13  2020   203.43
# 14  2021   240.71
# 15  2022   233.13
# 16  2023   196.77

# %%
# Plot
plt.figure(figsize=(10, 6))
plt.bar(revenue_SAM_df['Year'], revenue_SAM_df['Revenue'], color='skyblue')
plt.title('Samsung Annual Revenue Over Time')
plt.xlabel('Year')
plt.ylabel('Annual Revenue ($US Billion)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(revenue_SAM_df['Year'], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Samsung Stock Prices Over Years

# %%
import yfinance as yf

# Define the ticker symbol
ticker_symbol_SAM = 'SSNLF'

# Fetch stock prices
stock_prices_SAM = yf.download(ticker_symbol_SAM, start='2005-01-01', end='2024-03-16')

stock_prices_SAM.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#              Open   High    Low  Close     Adj Close  Volume
# Date
# 2005-01-03  8.345  8.345  8.345  8.345 -9.163345e+27   11500
# 2005-01-04  8.345  8.345  8.345  8.345 -9.163345e+27   16000
# 2005-01-05  8.345  8.345  8.345  8.345 -9.163345e+27   16000
# 2005-01-06  8.345  8.345  8.345  8.345 -9.163345e+27   16000
# 2005-01-07  8.345  8.345  8.345  8.345 -9.163345e+27   15500

# %%
# Plot
plt.figure(figsize=(12, 6))
plt.plot(stock_prices_SAM.index, stock_prices_SAM['Close'], color='blue')
plt.title('Stock Prices of Samsung Over Years')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Samsung Net Income over Years

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create the data dictionary
data = {
    'Year': [2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
    'Earnings ($US Billion)': [10.54, 6.24, 10.21, 16.69, 15.21, 27.42, 35.35, 26.44, 22.65, 26.59, 50.37, 55.67, 26.14, 31.26, 45.85, 35.85, 0.49]
}

# Create DataFrame
net_income_SAM_df = pd.DataFrame(data)

# Convert 'Year' to categorical variable
net_income_SAM_df['Year'] = net_income_SAM_df['Year'].astype(str)


# Display DataFrame
net_income_SAM_df
# Out:
#     Year  Earnings ($US Billion)
# 0   2007                   10.54
# 1   2008                    6.24
# 2   2009                   10.21
# 3   2010                   16.69
# 4   2011                   15.21
# 5   2012                   27.42
# 6   2013                   35.35
# 7   2014                   26.44
# 8   2015                   22.65
# 9   2016                   26.59
# 10  2017                   50.37
# 11  2018                   55.67
# 12  2019                   26.14
# 13  2020                   31.26
# 14  2021                   45.85
# 15  2022                   35.85
# 16  2023                    0.49

# %%
# Plot
plt.figure(figsize=(10, 6))
plt.bar(net_income_SAM_df['Year'], net_income_SAM_df['Earnings ($US Billion)'], color='skyblue')
plt.title('Samsung Net Income Over Years')
plt.xlabel('Year')
plt.ylabel('Net Income ($US Billion)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **SAMSUNG VS APPLE**

# %% [markdown]
# ## Saumsung and Apple Mission,Vision and Values

# %% [markdown]
# ### **SAMSUNG Mission and Vision**
#
# Samsung follows a simple business philosophy: to devote its talent and technology to creating superior products and services that contribute to a better global society. To achieve this, Samsung sets a high value on its people and technologies.
#
# ### **Values and Principles of Samsung**
# **People**
# Quite simply, a company is its people. At Samsung, we’re dedicated to giving our people a wealth of opportunities to reach their full potential.
#
# **Excellence**
# Everything we do at Samsung is driven by an unyielding passion for excellence and an unfaltering commitment to develop the best products and services on the market
#
# **Change**
# As we have done since our foundation, we set our sights on the future, anticipating market needs and demands so we can steer our company toward long-term success.
#
# **Integrity**
# Operating in an ethical way is the foundation of our business. Everything we do is guided by a moral compass that ensures fairness, respect for all stakeholders and complete transparency.
#
# **Co-prosperity**
# Samsung is committed to becoming a socially and environmentally responsible corporate citizen in all of its communities worldwide.
#
# ### **Apple’s mission statement is:**
#
# To bringing the best user experience to customers through innovative hardware, software, and services.
#
# ### **Values and Principles of Apple**
# **Accessibility**
# Technology is most powerful when everyone can make their mark.
#
# **Environment**
# Our goal is to leave the planet better than we found it.
#
# **Privacy**
# We design Apple products to protect your privacy and give you control over your information.
#
# **Supplier Responsibility**
# We believe in a safe, respectful, and supportive workplace for everyone.

# %% [markdown]
# ## Samsung and Apple Detailed Information

# %% [markdown]
# ### Samsung Information

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Apple Information

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Samsung and Apple Fiscal year details

# %% [markdown]
# **SAMSUNG**
# * Samsung Last Fiscal Year End: 2023-12-31
# * Samsung Next Fiscal Year End: 2024-12-31
# * Samsung Most Recent Quarter: 2023-12-31
#
# **APPLE**
# * Apple Last Fiscal Year End: 2023-09-30
# * Apple Next Fiscal Year End: 2024-09-30
# * Apple Most Recent Quarter: 2023-12-30

# %% [markdown]
# ## Content Information of Samsung and Apple

# %% [markdown]
# This table compares various content categories found on the official websites of Apple and Samsung. It outlines the diverse offerings of both companies, including their product lineups, services, support and customer care options, corporate information, as well as their focus on innovation and technology. This comparison provides insights into the range of content provided by each company to engage with customers, investors, and the public.

# %% [markdown]
# ![Screenshot 2024-03-17 031751.png](data:image/png;base64,...)

# %% [markdown]
# ## Market Capital of Samsung Vs Apple Over Years

# %%
# Plotting the data

plt.figure(figsize=(10, 6))

# Plot Samsung Market Capital
plt.plot(cap_SAM_df['Year'], cap_SAM_df['Market Cap (in Billion $)'], marker='o', label='Samsung')

# Plot Apple Market Capital
plt.plot(cap_AAPL_df['Year'], cap_AAPL_df['Market Cap (in Billion $)'], marker='o', label='Apple')

# Set Title and Labels
plt.title('Market Capitalization Trends: Samsung vs Apple')
plt.xlabel('Year')
plt.ylabel('Market Cap (in Billion $)')

plt.legend()

plt.grid(True)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ## Stock Prices of Samsung Vs Apple Over Years

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))

# Plot Apple stock prices
ax.plot(stock_prices_AAPL.index, stock_prices_AAPL['Close'], label='Apple', color='blue')

# Plot Samsung stock prices
ax.plot(stock_prices_SAM.index, stock_prices_SAM['Close'], label='Samsung', color='red')

# Set title and labels
ax.set_title('Stock Prices of Apple and Samsung Over Years')
ax.set_xlabel('Year')
ax.set_ylabel('Closing Price (USD)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add grid
ax.grid(True, linestyle='--', alpha=0.5)

# Add legend
ax.legend()

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Conclusion:**
#
# * Samsung's stock prices experienced fluctuations, with periods of stability and volatility, reflecting investor sentiment and market conditions.
#
# * Apple's stock prices showcased consistent growth over time, indicating investor confidence and market demand for the company's products.

# %% [markdown]
# ## Annual Revenue of Samsung Vs Apple

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))

# Plot Samsung revenue
ax.plot(revenue_SAM_df['Year'], revenue_SAM_df['Revenue'], label='Samsung', color='blue')

# Plot Apple revenue
ax.plot(revenue_AAPL_df['Year'], revenue_AAPL_df['Revenue'], label='Apple', color='red')

# Set title and labels
ax.set_title('Samsung and Apple Revenue Over Time')
ax.set_xlabel('Year')
ax.set_ylabel('Revenue ($US Billion)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add grid
ax.grid(True, linestyle='--', alpha=0.7)

# Add legend
ax.legend()

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### **Conclusion:**
#
# * Samsung's revenue exhibited fluctuations over the years, with periods of growth and decline, indicating varying market dynamics and business performance.
#
#
#
# * Apple's revenue consistently increased over the years, indicating steady growth and market dominance in the technology industry.

# %% [markdown]
# ## Net Income(Earnings) of Samsung Vs Apple Over Years

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, ax = plt.subplots(figsize=(12, 6))

# Plot Samsung net income
ax.plot(net_income_SAM_df['Year'], net_income_SAM_df['Earnings ($US Billion)'], label='Samsung', color='blue')

# Plot Apple net income
ax.plot(net_income_AAPL_df['Year'], net_income_AAPL_df['Net Income ($US Billion)'], label='Apple', color='red')

# Set title and labels
ax.set_title('Samsung and Apple Net Income Over Years')
ax.set_xlabel('Year')
ax.set_ylabel('Net Income ($US Billion)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add grid
ax.grid(True, linestyle='--', alpha=0.7)

# Add legend
ax.legend()

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### **Conclusion:**
#
# * Samsung's net income fluctuated significantly over the years, reflecting the company's varying profitability and financial performance.
#
# * Apple's net income demonstrated consistent growth over the years, highlighting the company's strong financial performance and profitability.

# %% [markdown]
# ## Global Smartphone Market Share Information

# %% [markdown]
# * As of 2023, for the **first time ever, *Apple ranked as the market leader* in the global smartphone market with a 20.1 percent share of all shipments**.
#
# * **Samsung ranked second, holding 19.4 percent of the market share.**
#
# * Samsung has seen its popularity steadily increase since it held just a 4.3 percent of the smartphone vendor market at the beginning of 2010. Samsung’s share of the overall mobile phone market, has fluctuated in recent times, dropping to under 20 percent in the most recent year.
#
# * Apple became smartphone market leader based on shipments in 2023. Apple’s smartphone sales are relatively cyclical and peak at the fourth quarter each year. In the fourth quarter of 2023, 24.7 percent of all smartphones new smartphones sold were iPhones. The iPhone generated considerable revenue for Apple with sales of the device amounting to over 200 billion U.S. dollars in their 2023 financial year.

# %% [markdown]
# ## Analysis between Apple and Samsung Electronics based on Porter's Five Forces model:

# %% [markdown]
# ### **Porter's Five Forces Analysis: Apple vs. Samsung Electronics**
# 1. **Threat of New Entrants**:
# ***Apple:***
# High Entry Barriers: Significant capital requirements for R&D, manufacturing, and distribution limit the threat of new entrants.
# Strong Brand Loyalty: Apple's loyal customer base and brand image create high barriers to entry for new competitors.
#
# ***Samsung Electronics:***
# Moderate Entry Barriers: While substantial capital is needed, Samsung's diversified business model and global presence may deter potential new entrants.
# Established Brand Reputation: Samsung's brand recognition and wide product portfolio contribute to barriers against new competitors.
#
# 2. **Bargaining Power of Suppliers:**
# ***Apple:***
# Limited Supplier Dependence: Apple's large-scale production and diverse supplier base reduce dependency on any single supplier, giving it bargaining power.
# Innovative Supplier Relationships: Apple often collaborates with suppliers to develop unique components, enhancing its bargaining position.
#
# ***Samsung Electronics:***
# Diverse Supplier Base: Samsung's extensive network of suppliers mitigates supplier power, allowing it to negotiate favorable terms.
# Vertical Integration: Samsung's vertical integration across various stages of production provides leverage in supplier negotiations.
#
# 3. **Bargaining Power of Buyers:**
# ***Apple:***
# High Buyer Loyalty: Apple's loyal customer base and brand image reduce buyer power, as consumers often prioritize Apple products.
# Differentiated Product Offerings: Unique features and design elements in Apple products lessen the impact of price sensitivity.
#
# ***Samsung Electronics:***
# Moderate Buyer Power: While Samsung faces competition, its diverse product range and technological advancements maintain buyer interest.
# Price Sensitivity in Certain Markets: Price competition in segments like smartphones may slightly increase buyer power.
#
# 4. **Threat of Substitutes:**
# ***Apple:***
# Limited Substitutes: Apple's ecosystem and proprietary software create a barrier to substitutes, although alternatives exist in the consumer electronics market.
# Brand Differentiation: Strong brand loyalty and ecosystem lock-in reduce the threat of substitutes.
#
# ***Samsung Electronics:***
# Moderate Substitution Threat: Samsung offers a wide range of products, but substitutes exist within each category, leading to moderate threat levels.
# Technological Advancements: Continuous innovation and technological advancements help mitigate the threat of substitutes.
# 5. **Competitive Rivalry:**
# ***Apple:***
# High Competition: Intense rivalry in the consumer electronics market from competitors like Samsung, Google, and Huawei.
# Brand Differentiation: Apple differentiates through design, user experience, and ecosystem integration to maintain market share.
#
# ***Samsung Electronics:***
# High Competition: Fierce rivalry with Apple and other tech giants across various product categories.
# Continuous Innovation: Samsung invests heavily in R&D to differentiate its products and compete effectively.
# This analysis provides insights into the competitive dynamics between Apple and Samsung Electronics, highlighting their respective strengths and weaknesses within the industry.

# %% [markdown]
# ## SWOT Analysis : Samsung Vs Apple

# %% [markdown]
# ### **Samsung**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Apple**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Summary of Comparison between Apple and Samsung Electronics:

# %% [markdown]
# ### **Market Positioning:**
#
# ***Apple:*** Known for its premium brand image, innovative design, and ecosystem lock-in.
#
# ***Samsung Electronics:*** Offers a diverse range of products across consumer electronics, with a strong global presence.
#
# ### **Competitive Advantage:**
#
# ***Apple:*** Differentiates through its proprietary software, seamless integration, and strong brand loyalty.
#
# ***Samsung Electronics:*** Leverages vertical integration, technological innovation, and a wide product portfolio to compete effectively.
#
# ### **Customer Base:**
#
# ***Apple:*** Commands a loyal customer base willing to pay premium prices for its products.
#
# ***Samsung Electronics:*** Targets a broad spectrum of consumers with diverse product offerings and price points.
#
# ### **Innovation and R&D:**
#
# ***Apple:*** Invests heavily in R&D to introduce groundbreaking technologies and maintain product differentiation.
#
# ***Samsung Electronics:*** Prioritizes innovation across various sectors, including semiconductor technology, displays, and consumer electronics.
#
# ### **Market Strategy:**
#
# ***Apple:*** Focuses on exclusivity, premium pricing, and brand appeal to drive sales and maintain margins.
#
# ***Samsung Electronics:*** Implements a more diversified strategy, catering to different market segments with varying product ranges and pricing.
#
# ### **Supply Chain and Manufacturing:**
#
# ***Apple:*** Relies on a global supply chain and outsourced manufacturing partners to meet demand for its products.
#
# ***Samsung Electronics:*** Benefits from vertical integration and a vast network of suppliers, enabling efficient production and cost management.
#
# ### **Brand Loyalty and Ecosystem:**
#
# ***Apple:*** Enjoys strong brand loyalty and ecosystem lock-in, with users invested in its hardware, software, and services.
#
# ***Samsung Electronics:*** Builds brand loyalty through product quality, innovation, and customer-centric approach across its diverse product lines.
#
# ### **Global Market Presence:**
#
# ***Apple:*** Dominates in developed markets, particularly North America and Europe, with a growing presence in emerging markets.
#
# ***Samsung Electronics:*** Has a strong foothold in both developed and emerging markets, leveraging its extensive distribution network and brand recognition.
# In essence, while Apple focuses on premium innovation and ecosystem integration, Samsung Electronics adopts a more diversified approach, catering to a broader range of consumers with its extensive product portfolio and technological advancements. Both companies fiercely compete in the global consumer electronics market, each leveraging its unique strengths to maintain market leadership and profitability.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Thankyou.**
